# %% [markdown]
# ## Khasi - Engineering

# %%
import import_ipynb
import clean_data
import pandas as pd
import modeling_2 as model
import numpy as np

# %%
df = clean_data.runAll()

# %%
df.head()
# Out:
#    UNITID  HIGHDEG    UGDS  UGDS_NRA  UGDS_UNKN  UGDS_WHITENH  UGDS_BLACKNH  \
# 0  100654        4  3852.0    0.0423     0.0003        0.0345        0.9125
# 1  100663        4  9889.0    0.0230     0.0250        0.6708        0.2468
# 2  100690        4    60.0    0.0000     0.0000        0.8000        0.0833
# 3  100706        4  3854.0    0.0327     0.0000        0.7613        0.1336
# 4  100724        4  4679.0    0.0062     0.0006        0.0560        0.9348
#
#    UGDS_API  UGDS_AIANOLD  UGDS_HISPOLD  ...  NPT4_75UP_  DEG_SCIMATH  \
# 0    0.0052        0.0029        0.0023  ...         0.0       0.1053
# 1    0.0237        0.0027        0.0080  ...         0.0       0.1696
# 2    0.1000        0.0000        0.0167  ...         0.0       0.0000
# 3    0.0361        0.0197        0.0166  ...         0.0       0.0846
# 4    0.0006        0.0002        0.0015  ...         0.0       0.1595
#
#    DEG_TENG  DEG_ART  DEG_PROF  DEG_HUM  DEG_LAW  DEG_MED  DEG_MIL  DEG_BUS
# ...
